# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
lstx = [1,2,3,4,5,6,7]
lsty = [1,2,3,5,8,13,20]
plt.plot(lstx,lsty)
plt.show();

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
plt.plot(lstx, linestyle='--', marker='o', markersize=10, linewidth=3, label='Normal')
plt.plot(lsty, linestyle='--', marker='o', markersize=10, linewidth=3, label='Fast')
plt.legend()
plt.show();

# %% [markdown]
# # Q4: Display multiple line charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
super_title = "my data visulaization assignment"

#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])

#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 10))
fig.suptitle(super_title, fontsize=15)

axs[0].plot(x_plot1,y_plot1)
axs[1].plot(x_plot2,y_plot2)
axs[2].plot(x_plot3,y_plot3)

axs[0].title.set_text('First Plot')
axs[1].title.set_text('Second Plot')
axs[2].title.set_text('Third Plot')

plt.show();

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
ser = ["sopranos1","sopranos2","sopranos3"]
rate = [10,9.5,9.8]
plt.bar(
    ser,
    rate,
    width=0.5,
    color=['r','b','g'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
carAge = [5,7,8,7,2,17,2,9,4,11]
carSpeed = [99,86,87,88,111,86,103,87,94,78]
colors = np.random.rand(10)
plt.scatter(
    carAge,
    carSpeed,
    c = colors,
    s=350,
    alpha=0.4
    
)
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Title")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 3>()
#       1 carAge = [5,7,8,7,2,17,2,9,4,11]
#       2 carSpeed = [99,86,87,88,111,86,103,87,94,78]
# ----> 3 colors = int(np.random.rand(10))
#       4 plt.scatter(
#       5     carAge,
#       6     carSpeed,
#    (...)
#      10
#      11 )
#      12 plt.xlabel("X label")
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
python_libraries = ["NumPy", "Pandas" ,"Matplotlib" ,"Seaborn" ,"Plotly", "Scikit-learn"]
skills  = [10,10,10,10,10,10]
plt.pie(
    skills,
    labels=python_libraries,
    colors = ['r','g','b','black','gray'],
    explode = [0,0,0,0,0,0.3],
    shadow = True
    
    
)
# Out:
# ([<matplotlib.patches.Wedge at 0x13ac3b80>,
#   <matplotlib.patches.Wedge at 0x13ace310>,
#   <matplotlib.patches.Wedge at 0x13acea60>,
#   <matplotlib.patches.Wedge at 0x13add1f0>,
#   <matplotlib.patches.Wedge at 0x13add940>,
#   <matplotlib.patches.Wedge at 0x13ac3b20>],
#  [Text(0.9526279355804298, 0.5500000148652441, 'NumPy'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, 'Pandas'),
#   Text(-0.9526279870751434, 0.5499999256737774, 'Matplotlib'),
#   Text(-0.952627884085708, -0.5500001040567056, 'Seaborn'),
#   Text(1.5448414935947287e-07, -1.0999999999999892, 'Plotly'),
#   Text(1.2124356854525344, -0.6999997918865714, 'Scikit-learn')])

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
x = np.random.randn(250)
plt.hist(x,bins = 15)
# Out:
# (array([ 2.,  6.,  9., 12., 18., 29., 44., 47., 31., 19., 16., 10.,  5.,
#          1.,  1.]),
#  array([-2.70736959, -2.31126702, -1.91516444, -1.51906186, -1.12295928,
#         -0.72685671, -0.33075413,  0.06534845,  0.46145103,  0.8575536 ,
#          1.25365618,  1.64975876,  2.04586134,  2.44196392,  2.83806649,
#          3.23416907]),
#  <BarContainer object of 15 artists>)
