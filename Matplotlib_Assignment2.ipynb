# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([1, 2, 3, 5, 8, 13, 20])

plt.plot(
    y, x,
    color='b', label='array line'
)
plt.show();

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
plt.plot(y, x, marker='o',markersize = 10, linewidth=3, linestyle='--', color='r', label='normal')
plt.plot(x, y, marker='o',markersize = 10, linewidth=3, linestyle='--', color='b', label='fast')
plt.legend()
plt.show();

# %% [markdown]
# # Q4: Display multiple line charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment

#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])

#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

axs[0].plot(x_plot1, y_plot1, color='r')
axs[0].set_title('first chart')

axs[1].plot(x_plot2, y_plot2, color='g')
axs[1].set_title('second chart')

axs[2].plot(x_plot3, y_plot3, color='b')
axs[2].set_title('third chart')

plt.suptitle('my data visulaization assignment')
plt.show()

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
top3Tv = np.array(['BB', 'GOT', 'OP'])
top3r = np.array([7.5, 9.2, 10])
plt.bar(
    x = top3Tv,
    height = top3r,
    width = 0.75,              # The width of the bin
    color = ['y', 'black', 'red'],   # The colors of the bins
    edgecolor = 'white',       # The edge color of the bins
)
plt.show()

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
carAge = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11])
carSpeed = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78])

plt.scatter(
    carAge, carSpeed,
    color=np.array(['b','g','y','w','r','c','m','k','purple','cyan']), alpha=0.4, s=350
)
plt.xlabel('Car Age', fontsize=16)
plt.ylabel('Car Speed', fontsize=16)
plt.show();

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
pythonLibraries = np.array(['NumPy','Pandas','Matplotlib','Seaborn','Scikit-learn','Plotly'])
skill = np.array([6,8,7,1,5,2])
plt.pie(
    skill, labels=pythonLibraries,
    autopct='%1.1f%%', startangle=90, colors=np.array(['darkblue','orange','cornflowerblue','lightseagreen','orchid','royalblue']),
    shadow=True, radius=1, explode = [0,0.3,0,0,0,0]
)
# Out:
# ([<matplotlib.patches.Wedge at 0x2781ce47380>,
#   <matplotlib.patches.Wedge at 0x2781ce45040>,
#   <matplotlib.patches.Wedge at 0x2781c7861b0>,
#   <matplotlib.patches.Wedge at 0x2781c77a540>,
#   <matplotlib.patches.Wedge at 0x2781c7837a0>,
#   <matplotlib.patches.Wedge at 0x2781c7837d0>],
#  [Text(-0.665691655090025, 0.8757023583064644, 'NumPy'),
#   Text(-1.1587645669814495, -0.7856619364003161, 'Pandas'),
#   Text(0.6656916550900254, -0.8757023583064641, 'Matplotlib'),
#   Text(1.0983867555967364, -0.05955279279492543, 'Seaborn'),
#   Text(0.910457888505938, 0.6173057858608721, 'Scikit-learn'),
#   Text(0.23646745821964457, 1.0742826170068753, 'Plotly')],
#  [Text(-0.3631045391400136, 0.47765583180352594, '20.7%'),
#   Text(-0.7449200787737889, -0.5050683876859174, '27.6%'),
#   Text(0.36310453914001384, -0.47765583180352583, '24.1%'),
#   Text(0.5991200485073107, -0.03248334152450478, '3.4%'),
#   Text(0.4966133937305116, 0.33671224683320294, '17.2%'),
#   Text(0.12898224993798793, 0.5859723365492047, '6.9%')])

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
mylist = [np.random.normal(100, 1, 250)]
plt.hist(mylist, bins=15, edgecolor='white')
plt.show();
